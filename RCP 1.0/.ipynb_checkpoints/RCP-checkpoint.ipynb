# %% [markdown]
# # Hand tracking

# %%
import cv2
import mediapipe as mp
import time
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-e4e3172915c1> in <module>
# ----> 1 import cv2
#       2 import mediapipe as mp
#       3 import time
#       4 from datetime import datetime
#
# ModuleNotFoundError: No module named 'cv2'

# %%
class handDetector():
    def __init__(self, mode = False, maxHands = 6, modelComplex = 1, detectionCon = 0.5, trackCon = 0.5):
        self.mode = mode
        self.maxHands = maxHands
        self.modelComplex = modelComplex
        self.detectionCon = detectionCon
        self.trackCon = trackCon

        self.mpHands = mp.solutions.hands
        self.hands = self.mpHands.Hands(self.mode, self.maxHands, self.modelComplex, self.detectionCon, self.trackCon)
        self.mpDraw = mp.solutions.drawing_utils
        
    def findHands(self,img, draw = True):
        imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        self.results = self.hands.process(imgRGB)
        # print(results.multi_hand_landmarks)

        if self.results.multi_hand_landmarks:
            for handLms in self.results.multi_hand_landmarks:
                if draw:
                    self.mpDraw.draw_landmarks(img, handLms, self.mpHands.HAND_CONNECTIONS)
        return img

#     def findPosition(self, img, handNo = 0, draw = True):

#         lmlist = []
#         hand_count = 0
#         if self.results.multi_hand_landmarks:
#             for hand in self.results.multi_hand_landmarks:
#                 hand_count += 1
#             myHand = self.results.multi_hand_landmarks[hand_count-1]
#             for id, lm in enumerate(myHand.landmark):
#                 h, w, c = img.shape
#                 cx, cy = int(lm.x * w), int(lm.y * h)
#                 lmlist.append([id, cx, cy])
#                 if draw:
#                     cv2.circle(img, (cx, cy), 3, (255, 0, 255), cv2.FILLED)
#         return lmlist, hand_count
    
    def findPosition(self, img, handNo = 0, draw = True):

        all_lmlist = []
        hand_count = 0
        if self.results.multi_hand_landmarks:
            for hand in self.results.multi_hand_landmarks:
                hand_count += 1
                lmlist = []
                myHand = self.results.multi_hand_landmarks[hand_count-1]
                for id, lm in enumerate(myHand.landmark):
                    h, w, c = img.shape
                    cx, cy = int(lm.x * w), int(lm.y * h)
                    lmlist.append([id, cx, cy])
                    if draw:
                        cv2.circle(img, (cx, cy), 3, (255, 0, 255), cv2.FILLED)
                all_lmlist.append(lmlist)
        return all_lmlist, hand_count

# %%
pTime = 0
cTime = 0
cap = cv2.VideoCapture(0)
detector = handDetector()

while True:
    success, img = cap.read()
    img = detector.findHands(img)
    all_lmlist, hand_count = detector.findPosition(img)
    if len(all_lmlist) != 0:
        print("timestamp:", datetime.now().time())
#         print(all_lmlist)
        print("number of hands detected:", hand_count)
        for lmlist in all_lmlist:
            print("hand coordinates", [lmlist[4][1], lmlist[4][2]])
        print("\n")

    cTime = time.time()
    fps = 1 / (cTime - pTime)
    pTime = cTime
    
    cv2.putText(img, str(int(fps)), (10, 70), cv2.FONT_HERSHEY_PLAIN, 3, (0, 0, 0), 3)

    cv2.imshow("Image", img)
    cv2.waitKey(1)
# Out:
# timestamp: 22:03:38.689635
# number of hands detected: 1
# hand coordinates [1272, 600]
#
#
# timestamp: 22:03:38.751793
# number of hands detected: 1
# hand coordinates [1264, 601]
#
#
# timestamp: 22:03:38.817894
# number of hands detected: 1
# hand coordinates [1266, 617]
#
#
# timestamp: 22:03:38.890260
# number of hands detected: 1
# hand coordinates [1264, 619]
#
#
# timestamp: 22:03:38.957584
# number of hands detected: 1
# hand coordinates [1267, 612]
#
#
# timestamp: 22:03:39.018988
# number of hands detected: 1
# hand coordinates [1261, 610]
#
#
# timestamp: 22:03:39.094668
# number of hands detected: 1
# hand coordinates [1262, 608]
#
#
# timestamp: 22:03:39.162583
# number of hands detected: 1
# hand coordinates [1266, 603]
#
#
# timestamp: 22:03:39.233409
# number of hands detected: 1
# hand coordinates [1259, 609]
#
#
# timestamp: 22:03:39.297186
# number of hands detected: 1
# hand coordinates [1272, 606]
#
#
# timestamp: 22:03:39.376515
# number of hands detected: 1
# hand coordinates [1274, 610]
#
#
# timestamp: 22:03:39.438819
# number of hands detected: 1
# hand coordinates [1273, 610]
#
#
# timestamp: 22:03:39.509529
# number of hands detected: 1
# hand coordinates [1267, 608]
#
#
# timestamp: 22:03:39.574412
# number of hands detected: 1
# hand coordinates [1276, 613]
#
#
# timestamp: 22:03:39.648689
# number of hands detected: 1
# hand coordinates [1267, 613]
#
#
# timestamp: 22:03:39.717032
# number of hands detected: 1
# hand coordinates [1264, 610]
#
#
# timestamp: 22:03:39.779729
# number of hands detected: 1
# hand coordinates [1263, 612]
#
#
# timestamp: 22:03:39.854295
# number of hands detected: 1
# hand coordinates [1264, 615]
#
#
# timestamp: 22:03:39.919841
# number of hands detected: 1
# hand coordinates [1269, 616]
#
#
# timestamp: 22:03:39.993229
# number of hands detected: 1
# hand coordinates [1264, 617]
#
#
# timestamp: 22:03:40.060041
# number of hands detected: 1
# hand coordinates [1262, 611]
#
#
# timestamp: 22:03:40.130730
# number of hands detected: 1
# hand coordinates [1262, 617]
#
#
# timestamp: 22:03:40.194423
# number of hands detected: 1
# hand coordinates [1264, 619]
#
#
# timestamp: 22:03:40.262004
# number of hands detected: 1
# hand coordinates [1263, 616]
#
#
# timestamp: 22:03:40.341942
# number of hands detected: 1
# hand coordinates [1265, 622]
#
#
# timestamp: 22:03:40.399999
# number of hands detected: 1
# hand coordinates [1261, 619]
#
#
# timestamp: 22:03:40.467801
# number of hands detected: 1
# hand coordinates [1260, 626]
#
#
# timestamp: 22:03:40.548511
# number of hands detected: 1
# hand coordinates [1262, 630]
#
#
# timestamp: 22:03:40.611720
# number of hands detected: 1
# hand coordinates [1255, 625]
#
#
# timestamp: 22:03:40.673604
# number of hands detected: 1
# hand coordinates [1257, 640]
#
#
# timestamp: 22:03:40.753444
# number of hands detected: 1
# hand coordinates [1258, 623]
#
#
# timestamp: 22:03:40.815018
# number of hands detected: 1
# hand coordinates [1260, 633]
#
#
# timestamp: 22:03:40.878629
# number of hands detected: 1
# hand coordinates [1260, 621]
#
#
# timestamp: 22:03:40.954869
# number of hands detected: 1
# hand coordinates [1254, 630]
#
#
# timestamp: 22:03:41.020788
# number of hands detected: 1
# hand coordinates [1260, 623]
#
#
# timestamp: 22:03:41.088275
# number of hands detected: 1
# hand coordinates [1259, 625]
#
#
# timestamp: 22:03:41.169701
# number of hands detected: 1
# hand coordinates [1265, 626]
#
#
# timestamp: 22:03:41.227844
# number of hands detected: 1
# hand coordinates [1256, 614]
#
#
# timestamp: 22:03:41.292836
# number of hands detected: 1
# hand coordinates [1262, 631]
#
#
# timestamp: 22:03:41.367840
# number of hands detected: 1
# hand coordinates [1250, 637]
#
#
# timestamp: 22:03:41.445221
# number of hands detected: 2
# hand coordinates [452, 326]
# hand coordinates [1250, 609]
#
#
# timestamp: 22:03:41.510834
# number of hands detected: 2
# hand coordinates [481, 286]
# hand coordinates [1244, 579]
#
#
# timestamp: 22:03:41.587553
# number of hands detected: 2
# hand coordinates [511, 262]
# hand coordinates [1253, 570]
#
#
# timestamp: 22:03:41.653690
# number of hands detected: 2
# hand coordinates [533, 257]
# hand coordinates [1252, 574]
#
#
# timestamp: 22:03:41.733724
# number of hands detected: 2
# hand coordinates [536, 265]
# hand coordinates [1259, 592]
#
#
# timestamp: 22:03:41.824878
# number of hands detected: 2
# hand coordinates [546, 277]
# hand coordinates [1257, 620]
#
#
# timestamp: 22:03:41.898313
# number of hands detected: 2
# hand coordinates [544, 287]
# hand coordinates [1260, 634]
#
#
# timestamp: 22:03:41.976625
# number of hands detected: 2
# hand coordinates [540, 289]
# hand coordinates [1260, 647]
#
#
# timestamp: 22:03:42.059736
# number of hands detected: 2
# hand coordinates [532, 284]
# hand coordinates [1272, 674]
#
#
# timestamp: 22:03:42.141846
# number of hands detected: 2
# hand coordinates [523, 285]
# hand coordinates [1269, 682]
#
#
# timestamp: 22:03:42.235742
# number of hands detected: 2
# hand coordinates [521, 288]
# hand coordinates [1261, 685]
#
#
# timestamp: 22:03:42.312945
# number of hands detected: 2
# hand coordinates [520, 289]
# hand coordinates [1254, 688]
#
#
# timestamp: 22:03:42.372894
# number of hands detected: 2
# hand coordinates [518, 291]
# hand coordinates [1243, 684]
#
#
# timestamp: 22:03:42.454622
# number of hands detected: 2
# hand coordinates [520, 309]
# hand coordinates [1241, 683]
#
#
# timestamp: 22:03:42.515096
# number of hands detected: 2
# hand coordinates [506, 324]
# hand coordinates [1240, 681]
#
#
# timestamp: 22:03:42.579259
# number of hands detected: 2
# hand coordinates [418, 316]
# hand coordinates [1234, 678]
#
#
# timestamp: 22:03:42.657495
# number of hands detected: 1
# hand coordinates [1236, 675]
#
#
# timestamp: 22:03:42.710165
# number of hands detected: 1
# hand coordinates [1235, 673]
#
#
# timestamp: 22:03:42.774718
# number of hands detected: 1
# hand coordinates [1232, 673]
#
#
# timestamp: 22:03:42.839638
# number of hands detected: 1
# hand coordinates [1235, 671]
#
#
# timestamp: 22:03:42.917062
# number of hands detected: 1
# hand coordinates [1232, 670]
#
#
# timestamp: 22:03:42.983246
# number of hands detected: 1
# hand coordinates [1231, 670]
#
#
# timestamp: 22:03:43.048809
# number of hands detected: 1
# hand coordinates [1231, 670]
#
#
# timestamp: 22:03:43.121552
# number of hands detected: 1
# hand coordinates [1231, 671]
#
#
# timestamp: 22:03:43.186260
# number of hands detected: 1
# hand coordinates [1225, 665]
#
#
# timestamp: 22:03:43.264424
# number of hands detected: 1
# hand coordinates [1226, 603]
#
#
# timestamp: 22:03:43.328243
# number of hands detected: 1
# hand coordinates [1206, 538]
#
#
# timestamp: 22:03:43.393445
# number of hands detected: 1
# hand coordinates [1225, 611]
#
#
# timestamp: 22:03:43.531886
# number of hands detected: 1
# hand coordinates [1248, 702]
#
#
# timestamp: 22:03:43.607155
# number of hands detected: 1
# hand coordinates [1249, 722]
#
#
# timestamp: 22:03:43.669008
# number of hands detected: 1
# hand coordinates [1251, 717]
#
#
# timestamp: 22:03:43.752505
# number of hands detected: 1
# hand coordinates [1244, 728]
#
#
# timestamp: 22:03:43.811896
# number of hands detected: 1
# hand coordinates [1252, 735]
#
#
# timestamp: 22:03:43.873905
# number of hands detected: 1
# hand coordinates [1258, 743]
#
#
# timestamp: 22:03:43.951046
# number of hands detected: 1
# hand coordinates [1246, 723]
#
#
# timestamp: 22:03:59.959047
# number of hands detected: 1
# hand coordinates [124, 412]
#
#
# timestamp: 22:04:00.033231
# number of hands detected: 1
# hand coordinates [201, 322]
#
#
# timestamp: 22:04:00.098595
# number of hands detected: 1
# hand coordinates [220, 305]
#
#
# timestamp: 22:04:00.172317
# number of hands detected: 1
# hand coordinates [226, 292]
#
#
# timestamp: 22:04:00.236420
# number of hands detected: 1
# hand coordinates [225, 282]
#
#
# timestamp: 22:04:00.308022
# number of hands detected: 1
# hand coordinates [217, 275]
#
#
# timestamp: 22:04:00.371212
# number of hands detected: 1
# hand coordinates [219, 280]
#
#
# timestamp: 22:04:00.447876
# number of hands detected: 1
# hand coordinates [216, 286]
#
#
# timestamp: 22:04:00.513015
# number of hands detected: 1
# hand coordinates [246, 315]
#
#
# timestamp: 22:04:00.584904
# number of hands detected: 1
# hand coordinates [227, 312]
#
#
# timestamp: 22:04:00.648239
# number of hands detected: 1
# hand coordinates [209, 299]
#
#
# timestamp: 22:04:00.714302
# number of hands detected: 1
# hand coordinates [195, 296]
#
#
# timestamp: 22:04:00.793524
# number of hands detected: 1
# hand coordinates [210, 308]
#
#
# timestamp: 22:04:00.854304
# number of hands detected: 1
# hand coordinates [209, 324]
#
#
# timestamp: 22:04:00.932987
# number of hands detected: 1
# hand coordinates [217, 339]
#
#
# timestamp: 22:04:00.991903
# number of hands detected: 1
# hand coordinates [217, 339]
#
#
# timestamp: 22:04:01.069498
# number of hands detected: 1
# hand coordinates [210, 341]
#
#
# timestamp: 22:04:01.132792
# number of hands detected: 1
# hand coordinates [183, 335]
# timestamp: 22:04:01.206722
# number of hands detected: 1
# hand coordinates [177, 336]
#
#
# timestamp: 22:04:01.270440
# number of hands detected: 1
# hand coordinates [183, 341]
#
#
# timestamp: 22:04:01.334032
# number of hands detected: 1
# hand coordinates [162, 340]
#
#
# timestamp: 22:04:01.413318
# number of hands detected: 1
# hand coordinates [138, 353]
#
#
# timestamp: 22:04:01.473922
# number of hands detected: 1
# hand coordinates [145, 402]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/r_/36_vmnld25d6v2jd0n4yygjm0000gn/T/ipykernel_83574/43391966.py in <module>
#      23
#      24     cv2.imshow("Image", img)
# ---> 25     cv2.waitKey(1)
#
# KeyboardInterrupt:

# %%
# pTime = 0
# cTime = 0
# cap = cv2.VideoCapture(0)
# detector = handDetector()

# while True:
#     success, frame = cap.read()
#     img = detector.findHands(frame)
#     all_lmlist, hand_count = detector.findPosition(img)
#     if len(all_lmlist) != 0:
#         print("timestamp:", datetime.now().time())
# #         print(all_lmlist)
#         print("number of hands detected:", hand_count)
#         for lmlist in all_lmlist:
#             print("hand coordinates", [lmlist[4][1], lmlist[4][2]])
#         print("\n")

#     cTime = time.time()
#     fps = 1 / (cTime - pTime)
#     pTime = cTime
    
#     cv2.putText(img, str(int(fps)), (10, 70), cv2.FONT_HERSHEY_PLAIN, 3, (0, 0, 0), 3)

#     cv2.imshow("Image", img)
#     cv2.waitKey(1)

# %%
# cap = cv2.VideoCapture(0)
# hand_detector = handDetector()
# while True:
#     success, img = cap.read()
#     img = hand_detector.findHands(img)
#     cv2.imshow("Image", img)
#     cv2.waitKey(1)

# %% [markdown]
# # Ball Detector

# %%
from collections import deque
from imutils.video import VideoStream
import numpy as np
import argparse
import cv2
import imutils
import time

# %%
vs = VideoStream(src=0).start()
cap = cv2.VideoCapture(0)
pTime = 0
cTime = 0
hand_detector = handDetector()
purpleLower = (128,0,128)
purpleUpper = (216,191,216)
yellowLower = (22, 93, 0)
yellowUpper = (45, 255, 255)
pts = deque(maxlen=5)
while True:
    # grab the current frame
    success, frame = cap.read()
    img = hand_detector.findHands(frame)
#     cv2.imshow("Image", img)
#     cv2.waitKey(1)
    
    if frame is None:
        break
    # resize the frame, blur it, and convert it to the HSV
    # color space
    frame = imutils.resize(frame, width=600)
    blurred = cv2.GaussianBlur(frame, (11, 11), 0)
    hsv = cv2.cvtColor(blurred, cv2.COLOR_BGR2HSV)
    
    # construct a mask for the color "purple", then perform
    # a series of dilations and erosions to remove any small
    # blobs left in the mask
    mask1 = cv2.inRange(hsv, purpleLower, purpleUpper)
    mask2 = cv2.inRange(hsv, yellowLower, yellowUpper)
    mask = cv2.bitwise_or(mask1, mask2)
    mask = cv2.erode(mask, None, iterations=2)
    mask = cv2.dilate(mask, None, iterations=2)
    
    # find contours in the mask and initialize the current
    # (x, y) center of the ball
    cnts = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL,
        cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    center = None

    # only proceed if at least one contour was found
    if len(cnts) > 0:
        # find the largest contour in the mask, then use
        # it to compute the minimum enclosing circle and
        # centroid
        c = max(cnts, key=cv2.contourArea)
        ((x, y), radius) = cv2.minEnclosingCircle(c)
        M = cv2.moments(c)
        center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

        # only proceed if the radius meets a minimum size
        if radius > 20:
            # draw the circle and centroid on the frame,
            # then update the list of tracked points
            cv2.circle(frame, (int(x), int(y)), int(radius),
                (0, 255, 255), 2)
            cv2.circle(frame, center, 5, (0, 0, 255), -1)

    # update the points queue
    pts.appendleft(center)

    # loop over the set of tracked points
    for i in range(1, len(pts)):
        # if either of the tracked points are None, ignore
        # them
        if pts[i - 1] is None or pts[i] is None:
            continue

        # otherwise, compute the thickness of the line and
        # draw the connecting lines
        thickness = 1
        cv2.line(frame, pts[i - 1], pts[i], (0, 0, 255), thickness)

    all_lmlist, hand_count = hand_detector.findPosition(img)
        
    if len(all_lmlist) != 0:
        print("timestamp:", datetime.now().time())
#         print(all_lmlist)
        print("number of hands detected:", hand_count)
        for lmlist in all_lmlist:
            print("hand coordinates", [lmlist[4][1], lmlist[4][2]])
        print("\n")

    cTime = time.time()
    fps = 1 / (cTime - pTime)
    pTime = cTime
    
    cv2.putText(img, str(int(fps)), (10, 70), cv2.FONT_HERSHEY_PLAIN, 3, (0, 0, 0), 3)

    cv2.imshow("Image", frame)
#     cv2.waitKey(1)
#     # show the frame to our screen
#     cv2.imshow("Frame", frame)
    key = cv2.waitKey(1) & 0xFF
   
    # if the 'q' key is pressed, stop the loop
    if key == ord("q"):
        break
# Out:
# timestamp: 22:04:15.947570
# number of hands detected: 1
# hand coordinates [1048, 552]
#
#
# timestamp: 22:04:20.427440
# number of hands detected: 1
# hand coordinates [608, 566]
#
#
# timestamp: 22:04:20.501123
# number of hands detected: 1
# hand coordinates [535, 598]
#
#
# timestamp: 22:04:21.243677
# number of hands detected: 1
# hand coordinates [355, 136]
#
#
# timestamp: 22:04:21.321309
# number of hands detected: 1
# hand coordinates [339, 153]
#
#
# timestamp: 22:04:21.394914
# number of hands detected: 2
# hand coordinates [389, 120]
# hand coordinates [355, 157]
#
#
# timestamp: 22:04:21.471416
# number of hands detected: 2
# hand coordinates [440, 127]
# hand coordinates [360, 168]
#
#
# timestamp: 22:04:21.536356
# number of hands detected: 2
# hand coordinates [429, 160]
# hand coordinates [348, 207]
#
#
# timestamp: 22:04:21.606542
# number of hands detected: 2
# hand coordinates [389, 208]
# hand coordinates [368, 237]
#
#
# timestamp: 22:04:21.679604
# number of hands detected: 2
# hand coordinates [406, 253]
# hand coordinates [371, 263]
#
#
# timestamp: 22:04:21.740471
# number of hands detected: 2
# hand coordinates [410, 290]
# hand coordinates [387, 230]
#
#
# timestamp: 22:04:21.805093
# number of hands detected: 2
# hand coordinates [371, 326]
# hand coordinates [329, 299]
#
#
# timestamp: 22:04:21.886725
# number of hands detected: 2
# hand coordinates [352, 317]
# hand coordinates [315, 309]
#
#
# timestamp: 22:04:21.948424
# number of hands detected: 2
# hand coordinates [183, 311]
# hand coordinates [304, 381]
#
#
# timestamp: 22:04:22.011679
# number of hands detected: 2
# hand coordinates [225, 346]
# hand coordinates [258, 338]
#
#
# timestamp: 22:04:22.088142
# number of hands detected: 2
# hand coordinates [168, 334]
# hand coordinates [219, 364]
#
#
# timestamp: 22:04:22.172154
# number of hands detected: 2
# hand coordinates [256, 338]
# hand coordinates [167, 335]
#
#
# timestamp: 22:04:32.609369
# number of hands detected: 1
# hand coordinates [963, 570]
#
#
# timestamp: 22:04:32.676035
# number of hands detected: 1
# hand coordinates [1043, 602]
#
#
# timestamp: 22:04:32.751682
# number of hands detected: 1
# hand coordinates [1051, 597]
#
#
# timestamp: 22:04:32.815232
# number of hands detected: 1
# hand coordinates [1013, 602]
#
#
# timestamp: 22:04:32.907440
# number of hands detected: 1
# hand coordinates [927, 617]
#
#
# timestamp: 22:04:32.968741
# number of hands detected: 1
# hand coordinates [688, 541]
#
#
# timestamp: 22:04:34.988030
# number of hands detected: 1
# hand coordinates [163, 356]
#
#
# timestamp: 22:04:35.129912
# number of hands detected: 1
# hand coordinates [193, 340]
#
#
# timestamp: 22:04:35.257431
# number of hands detected: 1
# hand coordinates [255, 312]
#
#
# timestamp: 22:04:35.333922
# number of hands detected: 1
# hand coordinates [254, 375]
#
#
# timestamp: 22:04:35.400386
# number of hands detected: 1
# hand coordinates [265, 407]
#
#
# timestamp: 22:04:35.467331
# number of hands detected: 1
# hand coordinates [273, 381]
#
#
# timestamp: 22:04:35.536282
# number of hands detected: 1
# hand coordinates [248, 364]
#
#
# timestamp: 22:04:35.610298
# number of hands detected: 1
# hand coordinates [276, 373]
#
#
# timestamp: 22:04:35.678375
# number of hands detected: 1
# hand coordinates [284, 353]
#
#
# timestamp: 22:04:35.743416
# number of hands detected: 1
# hand coordinates [298, 353]
#
#
# timestamp: 22:04:35.807129
# number of hands detected: 1
# hand coordinates [304, 344]
#
#
# timestamp: 22:04:35.884566
# number of hands detected: 1
# hand coordinates [336, 355]
#
#
# timestamp: 22:04:35.947151
# number of hands detected: 1
# hand coordinates [350, 347]
#
#
# timestamp: 22:04:36.021079
# number of hands detected: 1
# hand coordinates [353, 364]
#
#
# timestamp: 22:04:36.086593
# number of hands detected: 1
# hand coordinates [340, 353]
#
#
# timestamp: 22:04:36.150942
# number of hands detected: 1
# hand coordinates [431, 450]
#
#
# timestamp: 22:04:36.241108
# number of hands detected: 2
# hand coordinates [383, 340]
# hand coordinates [432, 441]
#
#
# timestamp: 22:04:36.305999
# number of hands detected: 2
# hand coordinates [386, 360]
# hand coordinates [444, 451]
#
#
# timestamp: 22:04:36.370323
# number of hands detected: 2
# hand coordinates [378, 369]
# hand coordinates [415, 444]
#
#
# timestamp: 22:04:36.453752
# number of hands detected: 2
# hand coordinates [375, 369]
# hand coordinates [405, 459]
#
#
# timestamp: 22:04:36.542778
# number of hands detected: 2
# hand coordinates [364, 398]
# hand coordinates [380, 471]
#
#
# timestamp: 22:04:36.617311
# number of hands detected: 2
# hand coordinates [337, 393]
# hand coordinates [392, 481]
#
#
# timestamp: 22:04:36.683527
# number of hands detected: 2
# hand coordinates [341, 429]
# hand coordinates [381, 511]
#
#
# timestamp: 22:04:36.760781
# number of hands detected: 2
# hand coordinates [347, 461]
# hand coordinates [379, 546]
#
#
# timestamp: 22:04:36.822622
# number of hands detected: 2
# hand coordinates [374, 462]
# hand coordinates [368, 570]
#
#
# timestamp: 22:04:36.888606
# number of hands detected: 2
# hand coordinates [386, 476]
# hand coordinates [398, 600]
#
#
# timestamp: 22:04:36.963528
# number of hands detected: 2
# hand coordinates [394, 470]
# hand coordinates [401, 572]
#
#
# timestamp: 22:04:37.029265
# number of hands detected: 2
# hand coordinates [405, 479]
# hand coordinates [400, 566]
#
#
# timestamp: 22:04:37.105062
# number of hands detected: 2
# hand coordinates [421, 492]
# hand coordinates [407, 594]
#
#
# timestamp: 22:04:37.168241
# number of hands detected: 2
# hand coordinates [417, 502]
# hand coordinates [421, 595]
#
#
# timestamp: 22:04:37.243648
# number of hands detected: 3
# hand coordinates [770, 573]
# hand coordinates [420, 510]
# hand coordinates [425, 589]
#
#
# timestamp: 22:04:37.319651
# number of hands detected: 3
# hand coordinates [815, 670]
# hand coordinates [418, 510]
# hand coordinates [427, 596]
#
#
# timestamp: 22:04:37.418055
# number of hands detected: 3
# hand coordinates [764, 687]
# hand coordinates [424, 525]
# hand coordinates [420, 581]
#
#
# timestamp: 22:04:37.521631
# number of hands detected: 2
# hand coordinates [766, 753]
# hand coordinates [413, 558]
#
#
# timestamp: 22:04:37.593947
# number of hands detected: 3
# hand coordinates [385, 452]
# hand coordinates [786, 755]
# hand coordinates [382, 554]
#
#
# timestamp: 22:04:37.691733
# number of hands detected: 3
# hand coordinates [336, 437]
# hand coordinates [651, 594]
# hand coordinates [398, 521]
#
#
# timestamp: 22:04:37.768658
# number of hands detected: 3
# hand coordinates [342, 434]
# hand coordinates [633, 593]
# hand coordinates [401, 500]
#
#
# timestamp: 22:04:37.868867
# number of hands detected: 3
# hand coordinates [348, 419]
# hand coordinates [630, 587]
# hand coordinates [420, 461]
#
#
# timestamp: 22:04:37.978238
# number of hands detected: 3
# hand coordinates [336, 415]
# hand coordinates [615, 576]
# hand coordinates [423, 451]
#
#
# timestamp: 22:04:38.073196
# number of hands detected: 3
# hand coordinates [306, 454]
# hand coordinates [609, 581]
# hand coordinates [414, 453]
#
#
# timestamp: 22:04:38.200647
# number of hands detected: 4
# hand coordinates [657, 558]
# hand coordinates [310, 420]
# hand coordinates [612, 573]
# hand coordinates [405, 482]
#
#
# timestamp: 22:04:38.277401
# number of hands detected: 3
# hand coordinates [354, 427]
# hand coordinates [606, 563]
# hand coordinates [407, 500]
#
#
# timestamp: 22:04:38.391894
# number of hands detected: 4
# hand coordinates [639, 624]
# hand coordinates [392, 419]
# hand coordinates [566, 540]
# hand coordinates [378, 440]
#
#
# timestamp: 22:04:38.485563
# number of hands detected: 3
# hand coordinates [391, 398]
# hand coordinates [540, 553]
# hand coordinates [387, 407]
#
#
# timestamp: 22:04:38.562004
# number of hands detected: 3
# hand coordinates [401, 396]
# hand coordinates [525, 539]
# hand coordinates [384, 406]
#
#
# timestamp: 22:04:38.676391
# number of hands detected: 4
# hand coordinates [626, 501]
# hand coordinates [388, 430]
# hand coordinates [523, 538]
# hand coordinates [389, 413]
#
#
# timestamp: 22:04:38.763319
# number of hands detected: 3
# hand coordinates [620, 513]
# hand coordinates [502, 541]
# hand coordinates [378, 422]
#
#
# timestamp: 22:04:38.873210
# number of hands detected: 3
# hand coordinates [600, 521]
# hand coordinates [505, 563]
# hand coordinates [381, 400]
#
#
# timestamp: 22:04:38.970229
# number of hands detected: 3
# hand coordinates [609, 511]
# hand coordinates [478, 592]
# hand coordinates [384, 398]
#
#
# timestamp: 22:04:39.051830
# number of hands detected: 4
# hand coordinates [376, 379]
# hand coordinates [605, 505]
# hand coordinates [463, 609]
# hand coordinates [387, 387]
#
#
# timestamp: 22:04:39.151069
# number of hands detected: 4
# hand coordinates [252, 366]
# hand coordinates [579, 529]
# hand coordinates [465, 607]
# hand coordinates [380, 393]
# timestamp: 22:04:39.247504
# number of hands detected: 3
# hand coordinates [360, 367]
# hand coordinates [468, 610]
# hand coordinates [396, 424]
#
#
# timestamp: 22:04:39.358028
# number of hands detected: 4
# hand coordinates [570, 524]
# hand coordinates [440, 358]
# hand coordinates [491, 593]
# hand coordinates [405, 516]
#
#
# timestamp: 22:04:39.454049
# number of hands detected: 3
# hand coordinates [458, 355]
# hand coordinates [503, 594]
# hand coordinates [484, 574]
#
#
# timestamp: 22:04:39.564039
# number of hands detected: 4
# hand coordinates [601, 489]
# hand coordinates [469, 372]
# hand coordinates [475, 603]
# hand coordinates [491, 633]
#
#
# timestamp: 22:04:39.672654
# number of hands detected: 4
# hand coordinates [618, 469]
# hand coordinates [432, 401]
# hand coordinates [473, 637]
# hand coordinates [471, 618]
#
#
# timestamp: 22:04:39.770782
# number of hands detected: 4
# hand coordinates [596, 484]
# hand coordinates [457, 391]
# hand coordinates [538, 617]
# hand coordinates [479, 564]
#
#
# timestamp: 22:04:39.879950
# number of hands detected: 4
# hand coordinates [631, 521]
# hand coordinates [388, 505]
# hand coordinates [598, 616]
# hand coordinates [375, 521]
#
#
# timestamp: 22:04:39.978462
# number of hands detected: 2
# hand coordinates [312, 299]
# hand coordinates [365, 442]
#
#
# timestamp: 22:04:40.073378
# number of hands detected: 2
# hand coordinates [339, 327]
# hand coordinates [318, 347]
#
#
# timestamp: 22:04:40.159549
# number of hands detected: 1
# hand coordinates [316, 308]
#
#
# timestamp: 22:04:40.243365
# number of hands detected: 1
# hand coordinates [340, 291]
#
#
# timestamp: 22:04:40.302595
# number of hands detected: 2
# hand coordinates [359, 304]
# hand coordinates [380, 281]
#
#
# timestamp: 22:04:40.361450
# number of hands detected: 1
# hand coordinates [407, 309]
#
#
# timestamp: 22:04:40.431725
# number of hands detected: 1
# hand coordinates [425, 338]
#
#
# timestamp: 22:04:40.512920
# number of hands detected: 2
# hand coordinates [401, 382]
# hand coordinates [422, 371]
#
#
# timestamp: 22:04:40.562081
# number of hands detected: 1
# hand coordinates [409, 400]
#
#
# timestamp: 22:04:40.655653
# number of hands detected: 2
# hand coordinates [345, 415]
# hand coordinates [381, 414]
#
#
# timestamp: 22:04:40.703954
# number of hands detected: 1
# hand coordinates [356, 416]
#
#
# timestamp: 22:04:40.765740
# number of hands detected: 1
# hand coordinates [308, 393]
#
#
# timestamp: 22:04:40.846633
# number of hands detected: 1
# hand coordinates [258, 396]
#
#
# timestamp: 22:04:40.909901
# number of hands detected: 1
# hand coordinates [190, 375]
#
#
# timestamp: 22:04:41.664817
# number of hands detected: 1
# hand coordinates [275, 220]
#
#
# timestamp: 22:04:41.729207
# number of hands detected: 1
# hand coordinates [325, 234]
#
#
# timestamp: 22:04:41.806323
# number of hands detected: 1
# hand coordinates [381, 249]
#
#
# timestamp: 22:04:41.874448
# number of hands detected: 1
# hand coordinates [437, 256]
#
#
# timestamp: 22:04:41.956700
# number of hands detected: 1
# hand coordinates [486, 276]
#
#
# timestamp: 22:04:42.013318
# number of hands detected: 1
# hand coordinates [502, 349]
#
#
# timestamp: 22:04:42.079667
# number of hands detected: 1
# hand coordinates [487, 405]
#
#
# timestamp: 22:04:42.146299
# number of hands detected: 1
# hand coordinates [496, 432]
#
#
# timestamp: 22:04:42.219802
# number of hands detected: 1
# hand coordinates [506, 464]
#
#
# timestamp: 22:04:42.283235
# number of hands detected: 1
# hand coordinates [520, 489]
#
#
# timestamp: 22:04:42.356807
# number of hands detected: 1
# hand coordinates [538, 484]
#
#
# timestamp: 22:04:42.431444
# number of hands detected: 2
# hand coordinates [562, 360]
# hand coordinates [533, 520]
#
#
# timestamp: 22:04:42.508030
# number of hands detected: 2
# hand coordinates [492, 384]
# hand coordinates [533, 542]
#
#
# timestamp: 22:04:42.573009
# number of hands detected: 2
# hand coordinates [511, 394]
# hand coordinates [540, 545]
#
#
# timestamp: 22:04:42.637501
# number of hands detected: 2
# hand coordinates [465, 399]
# hand coordinates [549, 542]
#
#
# timestamp: 22:04:42.714772
# number of hands detected: 2
# hand coordinates [449, 402]
# hand coordinates [566, 510]
#
#
# timestamp: 22:04:42.782038
# number of hands detected: 2
# hand coordinates [454, 446]
# hand coordinates [512, 569]
#
#
# timestamp: 22:04:42.845335
# number of hands detected: 2
# hand coordinates [426, 478]
# hand coordinates [533, 545]
#
#
# timestamp: 22:04:42.919841
# number of hands detected: 2
# hand coordinates [418, 495]
# hand coordinates [518, 553]
#
#
# timestamp: 22:04:42.986344
# number of hands detected: 2
# hand coordinates [471, 495]
# hand coordinates [483, 581]
#
#
# timestamp: 22:04:43.050787
# number of hands detected: 2
# hand coordinates [451, 501]
# hand coordinates [485, 548]
#
#
# timestamp: 22:04:43.127628
# number of hands detected: 2
# hand coordinates [432, 531]
# hand coordinates [470, 546]
#
#
# timestamp: 22:04:43.186141
# number of hands detected: 1
# hand coordinates [449, 544]
#
#
# timestamp: 22:04:43.264791
# number of hands detected: 2
# hand coordinates [410, 515]
# hand coordinates [453, 532]
#
#
# timestamp: 22:04:43.330567
# number of hands detected: 2
# hand coordinates [417, 525]
# hand coordinates [426, 555]
#
#
# timestamp: 22:04:43.382500
# number of hands detected: 1
# hand coordinates [415, 543]
#
#
# timestamp: 22:04:43.461223
# number of hands detected: 1
# hand coordinates [408, 536]
#
#
# timestamp: 22:04:43.528405
# number of hands detected: 1
# hand coordinates [385, 544]
#
#
# timestamp: 22:04:43.592216
# number of hands detected: 1
# hand coordinates [352, 537]
#
#
# timestamp: 22:04:43.673424
# number of hands detected: 1
# hand coordinates [319, 535]
#
#
# timestamp: 22:04:43.731515
# number of hands detected: 1
# hand coordinates [294, 522]
#
#
# timestamp: 22:04:43.795700
# number of hands detected: 1
# hand coordinates [275, 478]
#
#
# timestamp: 22:04:43.872385
# number of hands detected: 1
# hand coordinates [258, 441]
#
#
# timestamp: 22:04:43.939064
# number of hands detected: 1
# hand coordinates [170, 438]
#
#
# timestamp: 22:04:44.017256
# number of hands detected: 1
# hand coordinates [138, 396]
#
#
# timestamp: 22:04:44.080341
# number of hands detected: 1
# hand coordinates [164, 343]
#
#
# timestamp: 22:04:44.915324
# number of hands detected: 1
# hand coordinates [296, 333]
#
#
# timestamp: 22:04:44.977540
# number of hands detected: 1
# hand coordinates [277, 308]
#
#
# timestamp: 22:04:45.039688
# number of hands detected: 1
# hand coordinates [247, 305]
#
#
# timestamp: 22:04:45.114712
# number of hands detected: 1
# hand coordinates [220, 297]
#
#
# timestamp: 22:04:45.177929
# number of hands detected: 1
# hand coordinates [195, 293]
#
#
# timestamp: 22:04:45.241431
# number of hands detected: 1
# hand coordinates [181, 281]
#
#
# timestamp: 22:04:45.318277
# number of hands detected: 1
# hand coordinates [196, 291]
#
#
# timestamp: 22:04:45.383723
# number of hands detected: 1
# hand coordinates [213, 304]
#
#
# timestamp: 22:04:45.459814
# number of hands detected: 1
# hand coordinates [248, 317]
#
#
# timestamp: 22:04:45.531186
# number of hands detected: 1
# hand coordinates [283, 321]
#
#
# timestamp: 22:04:45.591218
# number of hands detected: 1
# hand coordinates [317, 339]
#
#
# timestamp: 22:04:45.668706
# number of hands detected: 1
# hand coordinates [315, 322]
#
#
# timestamp: 22:04:45.813143
# number of hands detected: 1
# hand coordinates [445, 345]
#
#
# timestamp: 22:04:45.872310
# number of hands detected: 1
# hand coordinates [497, 388]
#
#
# timestamp: 22:04:45.939396
# number of hands detected: 1
# hand coordinates [546, 436]
#
#
# timestamp: 22:04:46.013547
# number of hands detected: 2
# hand coordinates [506, 357]
# hand coordinates [556, 448]
#
#
# timestamp: 22:04:46.091766
# number of hands detected: 2
# hand coordinates [529, 384]
# hand coordinates [578, 472]
#
#
# timestamp: 22:04:46.152917
# number of hands detected: 2
# hand coordinates [545, 400]
# hand coordinates [599, 490]
#
#
# timestamp: 22:04:46.218454
# number of hands detected: 2
# hand coordinates [565, 432]
# hand coordinates [595, 520]
#
#
# timestamp: 22:04:46.297986
# number of hands detected: 2
# hand coordinates [576, 451]
# hand coordinates [609, 531]
#
#
# timestamp: 22:04:46.363109
# number of hands detected: 2
# hand coordinates [583, 463]
# hand coordinates [606, 557]
#
#
# timestamp: 22:04:46.425569
# number of hands detected: 2
# hand coordinates [594, 460]
# hand coordinates [626, 555]
#
#
# timestamp: 22:04:46.506987
# number of hands detected: 2
# hand coordinates [600, 467]
# hand coordinates [640, 546]
#
#
# timestamp: 22:04:46.570715
# number of hands detected: 2
# hand coordinates [599, 467]
# hand coordinates [661, 554]
#
#
# timestamp: 22:04:46.635713
# number of hands detected: 2
# hand coordinates [605, 452]
# hand coordinates [665, 578]
#
#
# timestamp: 22:04:46.700892
# number of hands detected: 2
# hand coordinates [600, 452]
# hand coordinates [677, 596]
# timestamp: 22:04:46.781961
# number of hands detected: 2
# hand coordinates [623, 456]
# hand coordinates [679, 611]
#
#
# timestamp: 22:04:46.841965
# number of hands detected: 2
# hand coordinates [641, 460]
# hand coordinates [687, 629]
#
#
# timestamp: 22:04:46.921440
# number of hands detected: 2
# hand coordinates [657, 475]
# hand coordinates [677, 599]
#
#
# timestamp: 22:04:46.981275
# number of hands detected: 2
# hand coordinates [702, 512]
# hand coordinates [660, 575]
#
#
# timestamp: 22:04:47.045845
# number of hands detected: 2
# hand coordinates [713, 552]
# hand coordinates [688, 603]
#
#
# timestamp: 22:04:47.127950
# number of hands detected: 2
# hand coordinates [720, 583]
# hand coordinates [728, 643]
#
#
# timestamp: 22:04:47.175576
# number of hands detected: 1
# hand coordinates [680, 613]
#
#
# timestamp: 22:04:47.241786
# number of hands detected: 1
# hand coordinates [668, 627]
#
#
# timestamp: 22:04:47.316601
# number of hands detected: 1
# hand coordinates [683, 649]
#
#
# timestamp: 22:04:47.382670
# number of hands detected: 1
# hand coordinates [688, 679]
#
#
# timestamp: 22:04:47.471390
# number of hands detected: 2
# hand coordinates [610, 582]
# hand coordinates [645, 679]
#
#
# timestamp: 22:04:47.529406
# number of hands detected: 2
# hand coordinates [602, 605]
# hand coordinates [610, 663]
#
#
# timestamp: 22:04:47.604710
# number of hands detected: 2
# hand coordinates [596, 585]
# hand coordinates [597, 646]
#
#
# timestamp: 22:04:47.672374
# number of hands detected: 2
# hand coordinates [595, 562]
# hand coordinates [563, 596]
#
#
# timestamp: 22:04:47.730580
# number of hands detected: 1
# hand coordinates [585, 533]
#
#
# timestamp: 22:04:47.790015
# number of hands detected: 1
# hand coordinates [612, 512]
#
#
# timestamp: 22:04:47.868601
# number of hands detected: 1
# hand coordinates [632, 459]
#
#
# timestamp: 22:04:47.933285
# number of hands detected: 1
# hand coordinates [611, 438]
#
#
# timestamp: 22:04:47.997719
# number of hands detected: 1
# hand coordinates [560, 356]
#
#
# timestamp: 22:04:48.086450
# number of hands detected: 2
# hand coordinates [583, 400]
# hand coordinates [540, 335]
#
#
# timestamp: 22:04:48.151730
# number of hands detected: 2
# hand coordinates [559, 360]
# hand coordinates [516, 303]
#
#
# timestamp: 22:04:48.216979
# number of hands detected: 2
# hand coordinates [524, 370]
# hand coordinates [476, 303]
#
#
# timestamp: 22:04:48.295075
# number of hands detected: 2
# hand coordinates [452, 367]
# hand coordinates [453, 279]
#
#
# timestamp: 22:04:48.358070
# number of hands detected: 2
# hand coordinates [392, 392]
# hand coordinates [411, 252]
#
#
# timestamp: 22:04:48.433345
# number of hands detected: 2
# hand coordinates [353, 422]
# hand coordinates [341, 345]
#
#
# timestamp: 22:04:48.501247
# number of hands detected: 2
# hand coordinates [349, 385]
# hand coordinates [298, 323]
#
#
# timestamp: 22:04:48.566345
# number of hands detected: 2
# hand coordinates [417, 407]
# hand coordinates [313, 384]
#
#
# timestamp: 22:04:48.631707
# number of hands detected: 2
# hand coordinates [489, 525]
# hand coordinates [413, 418]
#
#
# timestamp: 22:04:48.708977
# number of hands detected: 3
# hand coordinates [558, 441]
# hand coordinates [598, 547]
# hand coordinates [499, 386]
#
#
# timestamp: 22:04:48.792250
# number of hands detected: 2
# hand coordinates [665, 547]
# hand coordinates [559, 355]
#
#
# timestamp: 22:04:48.875256
# number of hands detected: 2
# hand coordinates [700, 470]
# hand coordinates [617, 452]
#
#
# timestamp: 22:04:48.941724
# number of hands detected: 2
# hand coordinates [670, 367]
# hand coordinates [648, 387]
#
#
# timestamp: 22:04:49.023206
# number of hands detected: 1
# hand coordinates [631, 294]
#
#
# timestamp: 22:04:49.072808
# number of hands detected: 1
# hand coordinates [564, 321]
#
#
# timestamp: 22:04:49.162763
# number of hands detected: 1
# hand coordinates [408, 288]
#
#
# timestamp: 22:04:49.259235
# number of hands detected: 1
# hand coordinates [341, 224]
#
#
# timestamp: 22:04:49.620699
# number of hands detected: 1
# hand coordinates [354, 511]
#
#
# timestamp: 22:04:49.687137
# number of hands detected: 1
# hand coordinates [419, 434]
#
#
# timestamp: 22:04:49.770397
# number of hands detected: 2
# hand coordinates [482, 393]
# hand coordinates [483, 386]
#
#
# timestamp: 22:04:49.835329
# number of hands detected: 2
# hand coordinates [562, 361]
# hand coordinates [469, 321]
#
#
# timestamp: 22:04:49.903290
# number of hands detected: 1
# hand coordinates [467, 282]
#
#
# timestamp: 22:04:49.982578
# number of hands detected: 2
# hand coordinates [549, 348]
# hand coordinates [483, 240]
#
#
# timestamp: 22:04:50.050807
# number of hands detected: 2
# hand coordinates [530, 357]
# hand coordinates [440, 209]
#
#
# timestamp: 22:04:50.115430
# number of hands detected: 1
# hand coordinates [474, 337]
#
#
# timestamp: 22:04:50.178692
# number of hands detected: 1
# hand coordinates [399, 332]
#
#
# timestamp: 22:04:50.251426
# number of hands detected: 1
# hand coordinates [339, 330]
#
#
# timestamp: 22:04:50.318195
# number of hands detected: 1
# hand coordinates [275, 415]
#
#
# timestamp: 22:04:50.385065
# number of hands detected: 1
# hand coordinates [337, 430]
#
#
# timestamp: 22:04:50.518848
# number of hands detected: 1
# hand coordinates [286, 428]
#
#
# timestamp: 22:04:50.582796
# number of hands detected: 1
# hand coordinates [293, 527]
#
#
# timestamp: 22:04:50.675606
# number of hands detected: 2
# hand coordinates [389, 516]
# hand coordinates [360, 495]
#
#
# timestamp: 22:04:50.738125
# number of hands detected: 2
# hand coordinates [448, 457]
# hand coordinates [447, 441]
#
#
# timestamp: 22:04:50.791588
# number of hands detected: 1
# hand coordinates [451, 388]
#
#
# timestamp: 22:04:50.870376
# number of hands detected: 1
# hand coordinates [455, 355]
#
#
# timestamp: 22:04:50.938391
# number of hands detected: 1
# hand coordinates [466, 317]
#
#
# timestamp: 22:04:51.010112
# number of hands detected: 2
# hand coordinates [528, 468]
# hand coordinates [461, 319]
#
#
# timestamp: 22:04:51.078881
# number of hands detected: 2
# hand coordinates [512, 463]
# hand coordinates [456, 319]
#
#
# timestamp: 22:04:51.166169
# number of hands detected: 3
# hand coordinates [352, 331]
# hand coordinates [506, 462]
# hand coordinates [415, 299]
#
#
# timestamp: 22:04:51.262842
# number of hands detected: 3
# hand coordinates [389, 313]
# hand coordinates [485, 460]
# hand coordinates [400, 296]
#
#
# timestamp: 22:04:51.376006
# number of hands detected: 3
# hand coordinates [348, 361]
# hand coordinates [477, 465]
# hand coordinates [382, 304]
#
#
# timestamp: 22:04:51.470304
# number of hands detected: 3
# hand coordinates [274, 360]
# hand coordinates [438, 489]
# hand coordinates [316, 343]
#
#
# timestamp: 22:04:51.582495
# number of hands detected: 2
# hand coordinates [338, 388]
# hand coordinates [271, 338]
#
#
# timestamp: 22:04:51.679585
# number of hands detected: 2
# hand coordinates [371, 419]
# hand coordinates [358, 371]
#
#
# timestamp: 22:04:51.777459
# number of hands detected: 2
# hand coordinates [466, 478]
# hand coordinates [395, 424]
#
#
# timestamp: 22:04:51.845993
# number of hands detected: 3
# hand coordinates [448, 371]
# hand coordinates [479, 514]
# hand coordinates [446, 379]
#
#
# timestamp: 22:04:51.948704
# number of hands detected: 2
# hand coordinates [531, 413]
# hand coordinates [422, 273]
#
#
# timestamp: 22:04:52.009656
# number of hands detected: 2
# hand coordinates [501, 363]
# hand coordinates [427, 338]
#
#
# timestamp: 22:04:52.075227
# number of hands detected: 2
# hand coordinates [500, 287]
# hand coordinates [435, 307]
#
#
# timestamp: 22:04:52.149126
# number of hands detected: 1
# hand coordinates [424, 252]
#
#
# timestamp: 22:04:53.033947
# number of hands detected: 1
# hand coordinates [364, 445]
#
#
# timestamp: 22:04:53.100081
# number of hands detected: 1
# hand coordinates [388, 442]
#
#
# timestamp: 22:04:53.165289
# number of hands detected: 1
# hand coordinates [391, 427]
#
#
# timestamp: 22:04:53.239413
# number of hands detected: 1
# hand coordinates [372, 394]
#
#
# timestamp: 22:04:53.305579
# number of hands detected: 1
# hand coordinates [371, 359]
#
#
# timestamp: 22:04:53.374365
# number of hands detected: 1
# hand coordinates [339, 322]
#
#
# timestamp: 22:04:53.445519
# number of hands detected: 1
# hand coordinates [305, 275]
#
#
# timestamp: 22:04:53.526119
# number of hands detected: 1
# hand coordinates [405, 381]
#
#
# timestamp: 22:04:55.861312
# number of hands detected: 1
# hand coordinates [317, 269]
#
#
# timestamp: 22:04:55.928049
# number of hands detected: 1
# hand coordinates [373, 354]
#
#
# timestamp: 22:04:57.059454
# number of hands detected: 1
# hand coordinates [603, 464]
#
#
# timestamp: 22:04:57.200643
# number of hands detected: 1
# hand coordinates [763, 655]
# timestamp: 22:04:57.267361
# number of hands detected: 1
# hand coordinates [777, 729]
#
#
# timestamp: 22:04:57.331140
# number of hands detected: 1
# hand coordinates [742, 745]
#
#
# timestamp: 22:04:57.408684
# number of hands detected: 2
# hand coordinates [748, 605]
# hand coordinates [700, 597]
#
#
# timestamp: 22:04:57.475801
# number of hands detected: 1
# hand coordinates [741, 526]
#
#
# timestamp: 22:04:57.547640
# number of hands detected: 2
# hand coordinates [876, 551]
# hand coordinates [753, 527]
#
#
# timestamp: 22:04:57.617793
# number of hands detected: 1
# hand coordinates [839, 603]
#
#
# timestamp: 22:04:57.691114
# number of hands detected: 1
# hand coordinates [862, 678]
#
#
# timestamp: 22:04:57.744305
# number of hands detected: 1
# hand coordinates [834, 712]
#
#
# timestamp: 22:04:57.822802
# number of hands detected: 1
# hand coordinates [851, 803]
#
#
# timestamp: 22:04:57.897240
# number of hands detected: 2
# hand coordinates [813, 674]
# hand coordinates [844, 708]
#
#
# timestamp: 22:04:57.962282
# number of hands detected: 2
# hand coordinates [834, 585]
# hand coordinates [868, 633]
#
#
# timestamp: 22:04:58.039622
# number of hands detected: 2
# hand coordinates [858, 580]
# hand coordinates [859, 591]
#
#
# timestamp: 22:04:58.090958
# number of hands detected: 1
# hand coordinates [821, 598]
#
#
# timestamp: 22:04:58.168714
# number of hands detected: 2
# hand coordinates [808, 605]
# hand coordinates [770, 630]
#
#
# timestamp: 22:04:58.249864
# number of hands detected: 2
# hand coordinates [849, 647]
# hand coordinates [781, 650]
#
#
# timestamp: 22:04:58.320453
# number of hands detected: 2
# hand coordinates [803, 543]
# hand coordinates [746, 704]
#
#
# timestamp: 22:04:58.406628
# number of hands detected: 1
# hand coordinates [741, 531]
#
#
# timestamp: 22:04:58.472728
# number of hands detected: 1
# hand coordinates [690, 467]
#
#
# timestamp: 22:04:58.536313
# number of hands detected: 1
# hand coordinates [639, 383]
#
#
# timestamp: 22:04:58.614883
# number of hands detected: 1
# hand coordinates [611, 331]
#
#
# timestamp: 22:04:58.677388
# number of hands detected: 1
# hand coordinates [564, 297]
#
#
# timestamp: 22:04:58.750166
# number of hands detected: 1
# hand coordinates [512, 274]
#
#
# timestamp: 22:04:58.821895
# number of hands detected: 1
# hand coordinates [467, 257]
#
#
# timestamp: 22:04:58.890056
# number of hands detected: 1
# hand coordinates [418, 258]
#
#
# timestamp: 22:04:58.956310
# number of hands detected: 1
# hand coordinates [373, 273]
#
#
# timestamp: 22:04:59.038091
# number of hands detected: 1
# hand coordinates [355, 334]
#
#
# timestamp: 22:04:59.117645
# number of hands detected: 3
# hand coordinates [228, 200]
# hand coordinates [359, 352]
# hand coordinates [352, 374]
#
#
# timestamp: 22:04:59.200980
# number of hands detected: 2
# hand coordinates [242, 261]
# hand coordinates [378, 438]
#
#
# timestamp: 22:04:59.291549
# number of hands detected: 3
# hand coordinates [386, 321]
# hand coordinates [244, 299]
# hand coordinates [410, 480]
#
#
# timestamp: 22:04:59.386836
# number of hands detected: 2
# hand coordinates [492, 360]
# hand coordinates [494, 543]
#
#
# timestamp: 22:04:59.486826
# number of hands detected: 2
# hand coordinates [573, 378]
# hand coordinates [616, 538]
#
#
# timestamp: 22:04:59.549056
# number of hands detected: 2
# hand coordinates [618, 384]
# hand coordinates [678, 534]
#
#
# timestamp: 22:04:59.613387
# number of hands detected: 2
# hand coordinates [640, 395]
# hand coordinates [711, 534]
#
#
# timestamp: 22:04:59.692140
# number of hands detected: 2
# hand coordinates [689, 478]
# hand coordinates [757, 486]
#
#
# timestamp: 22:04:59.753987
# number of hands detected: 2
# hand coordinates [748, 456]
# hand coordinates [766, 444]
#
#
# timestamp: 22:04:59.819404
# number of hands detected: 1
# hand coordinates [758, 413]
#
#
# timestamp: 22:04:59.884037
# number of hands detected: 1
# hand coordinates [730, 367]
#
#
# timestamp: 22:04:59.949180
# number of hands detected: 1
# hand coordinates [719, 335]
#
#
# timestamp: 22:05:00.033901
# number of hands detected: 1
# hand coordinates [690, 317]
#
#
# timestamp: 22:05:00.091276
# number of hands detected: 1
# hand coordinates [643, 303]
#
#
# timestamp: 22:05:00.157607
# number of hands detected: 1
# hand coordinates [601, 290]
#
#
# timestamp: 22:05:00.222578
# number of hands detected: 1
# hand coordinates [554, 294]
#
#
# timestamp: 22:05:00.298965
# number of hands detected: 1
# hand coordinates [515, 297]
#
#
# timestamp: 22:05:00.365511
# number of hands detected: 1
# hand coordinates [467, 323]
#
#
# timestamp: 22:05:00.438709
# number of hands detected: 1
# hand coordinates [435, 347]
#
#
# timestamp: 22:05:00.526133
# number of hands detected: 1
# hand coordinates [422, 368]
#
#
# timestamp: 22:05:00.586281
# number of hands detected: 1
# hand coordinates [393, 402]
#
#
# timestamp: 22:05:00.649038
# number of hands detected: 1
# hand coordinates [372, 448]
#
#
# timestamp: 22:05:00.726709
# number of hands detected: 2
# hand coordinates [306, 294]
# hand coordinates [358, 489]
#
#
# timestamp: 22:05:00.795744
# number of hands detected: 2
# hand coordinates [277, 348]
# hand coordinates [351, 516]
#
#
# timestamp: 22:05:00.857646
# number of hands detected: 1
# hand coordinates [346, 534]
#
#
# timestamp: 22:05:00.923510
# number of hands detected: 2
# hand coordinates [291, 367]
# hand coordinates [378, 563]
#
#
# timestamp: 22:05:01.005424
# number of hands detected: 2
# hand coordinates [326, 389]
# hand coordinates [379, 494]
#
#
# timestamp: 22:05:01.066943
# number of hands detected: 2
# hand coordinates [368, 397]
# hand coordinates [452, 570]
#
#
# timestamp: 22:05:01.135109
# number of hands detected: 2
# hand coordinates [443, 412]
# hand coordinates [503, 567]
#
#
# timestamp: 22:05:01.198711
# number of hands detected: 2
# hand coordinates [492, 410]
# hand coordinates [561, 610]
#
#
# timestamp: 22:05:01.276074
# number of hands detected: 2
# hand coordinates [551, 410]
# hand coordinates [620, 579]
#
#
# timestamp: 22:05:01.341825
# number of hands detected: 2
# hand coordinates [552, 378]
# hand coordinates [674, 584]
#
#
# timestamp: 22:05:01.414708
# number of hands detected: 2
# hand coordinates [629, 390]
# hand coordinates [705, 566]
#
#
# timestamp: 22:05:01.481872
# number of hands detected: 2
# hand coordinates [670, 374]
# hand coordinates [729, 560]
#
#
# timestamp: 22:05:01.550484
# number of hands detected: 2
# hand coordinates [637, 341]
# hand coordinates [760, 488]
#
#
# timestamp: 22:05:01.612913
# number of hands detected: 2
# hand coordinates [660, 327]
# hand coordinates [768, 477]
#
#
# timestamp: 22:05:01.694429
# number of hands detected: 2
# hand coordinates [658, 313]
# hand coordinates [777, 453]
#
#
# timestamp: 22:05:01.756616
# number of hands detected: 2
# hand coordinates [685, 282]
# hand coordinates [759, 408]
#
#
# timestamp: 22:05:01.819660
# number of hands detected: 2
# hand coordinates [706, 344]
# hand coordinates [744, 386]
#
#
# timestamp: 22:05:01.896377
# number of hands detected: 2
# hand coordinates [735, 348]
# hand coordinates [727, 357]
#
#
# timestamp: 22:05:01.964131
# number of hands detected: 2
# hand coordinates [715, 337]
# hand coordinates [711, 339]
#
#
# timestamp: 22:05:02.018788
# number of hands detected: 1
# hand coordinates [682, 328]
#
#
# timestamp: 22:05:02.084082
# number of hands detected: 1
# hand coordinates [661, 323]
#
#
# timestamp: 22:05:02.160992
# number of hands detected: 1
# hand coordinates [618, 320]
#
#
# timestamp: 22:05:02.229541
# number of hands detected: 1
# hand coordinates [577, 327]
#
#
# timestamp: 22:05:02.291764
# number of hands detected: 1
# hand coordinates [545, 319]
#
#
# timestamp: 22:05:02.365214
# number of hands detected: 1
# hand coordinates [509, 319]
#
#
# timestamp: 22:05:02.429970
# number of hands detected: 1
# hand coordinates [476, 319]
#
#
# timestamp: 22:05:02.493940
# number of hands detected: 1
# hand coordinates [458, 326]
#
#
# timestamp: 22:05:02.572890
# number of hands detected: 1
# hand coordinates [428, 342]
#
#
# timestamp: 22:05:02.648695
# number of hands detected: 1
# hand coordinates [407, 369]
#
#
# timestamp: 22:05:02.712655
# number of hands detected: 1
# hand coordinates [388, 402]
#
#
# timestamp: 22:05:02.788901
# number of hands detected: 1
# hand coordinates [367, 442]
#
#
# timestamp: 22:05:02.851960
# number of hands detected: 1
# hand coordinates [349, 483]
#
#
# timestamp: 22:05:02.932739
# number of hands detected: 2
# hand coordinates [287, 331]
# hand coordinates [351, 520]
#
#
# timestamp: 22:05:03.023352
# number of hands detected: 2
# hand coordinates [274, 376]
# hand coordinates [354, 420]
#
#
# timestamp: 22:05:03.102296
# number of hands detected: 2
# hand coordinates [306, 413]
# hand coordinates [320, 435]
#
#
# timestamp: 22:05:03.168920
# number of hands detected: 2
# hand coordinates [282, 472]
# hand coordinates [310, 511]
#
#
# timestamp: 22:05:03.231896
# number of hands detected: 2
# hand coordinates [328, 477]
# hand coordinates [433, 617]
#
#
# timestamp: 22:05:03.321655
# number of hands detected: 2
# hand coordinates [506, 621]
# hand coordinates [520, 698]

# %% [markdown]
# # Accelerometer Data
